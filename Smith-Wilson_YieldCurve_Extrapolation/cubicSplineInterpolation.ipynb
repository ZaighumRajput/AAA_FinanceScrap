# %%
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d

# %%
SGPYieldCurve = pd.read_csv("YIELDCURVE-SGP.csv", index_col=0)

# %%
x = np.linspace(0,10,10)
y = np.cos(-x**2/8.0)
plot(x,y, 'go')

# %%
f = interp1d(x,y)
fCubic = interp1d(x,y, kind='cubic')

# %%
xnew = np.linspace(0,10,40) #denser
plot(x,y,'o', xnew,f(xnew), '-', xnew, fCubic(xnew), '--')

# %% [markdown]
# ## Spline Interpolation

# %%
from scipy import interpolate

# %%
x = np.arange(0,2*np.pi+np.pi/4, 2*np.pi/8)
y = np.sin(x)

# %%
tck = interpolate.splrep(x,y,s=0)
xnew = np.arange(0,2*np.pi+np.pi/4, 2*np.pi/50) #denser
ynew = interpolate.splev(xnew, tck, der=0)

# %%
plot(x,y, 'x', xnew, ynew)

# %% [markdown]
# You can also get derivative

# %%
yder = interpolate.splev(xnew, tck, der=1)
plot(xnew, yder)

# %%
yder = interpolate.splev(xnew, tck, der=2)
plot(xnew, yder)
