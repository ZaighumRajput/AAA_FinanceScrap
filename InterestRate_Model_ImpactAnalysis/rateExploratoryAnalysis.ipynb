# %%
import pandas as pd

# %%
rawRates = pd.read_csv("pooledRates.txt", index_col = 0)

# %%
rawRates["EUR_M3"].plot(title="Interest on 3M EUR bond", )

# %%
rawRates["JPY_M3"].plot()

# %%
rawRates["EUR_YR10"].plot(title="Interest on 10YR EUR bonds")

# %%
rawRates
# Out:
#               EUR_M3  EUR_M6  EUR_YR1  EUR_YR2  EUR_YR3  EUR_YR4  EUR_YR5  \
# Date
# 3/31/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 4/30/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 5/31/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 6/30/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 7/31/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 8/31/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 9/30/1989        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 10/31/1989       NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 11/30/1989       NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 12/31/1989       NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 1/31/1990        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# 2/28/1990        NaN     NaN      NaN      NaN      NaN      NaN      NaN
# ...
